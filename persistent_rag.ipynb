# %%
from sqlitesearch import TextSearchIndex

sqlite_index = TextSearchIndex(
    text_fields=["question", "section", "answer"],
    keyword_fields=["course"],
    db_path="faq.db"
)

# %%
sqlite_index.count()
# Out:
# 85

# %%
results = sqlite_index.search("Can I still join the course after it started?", num_results=2)
[doc["question"] for doc in results]
# Out:
# ['I just discovered the course. Can I still join?',
#  'How do I start using Google Gemini models in the Module 1 notebook through the OpenAI-compatible endpoint?']

# %%
from dotenv import load_dotenv
import os
from ollama import Client
from rag_helper import RAGBase
from dotenv import load_dotenv

load_dotenv()

client = Client(
    host="https://ollama.com",
    headers={'Authorization': 'Bearer ' + os.environ.get('OLLAMA_API_KEY')}
)

assistant = RAGBase(
    index=sqlite_index,
    llm_client=client,
)

# %%
answer = assistant.rag("Can I still join the course after it started?")
print(answer)
# Out:
# Yes—you can hop in even after the cohort has begun. Feel free to start watching the videos and doing the homework right away. Just keep in mind that if you want a certificate you’ll need to submit your capstone project before the submission window closes (the deadline for peer‑reviewing also applies). So you can join now; just be sure to finish and turn in your project while we’re still accepting submissions.None

# %%
sqlite_index.close()
