# %%
from dotenv import load_dotenv
load_dotenv()

# %%
from dotenv import load_dotenv
import os
from ollama import Client

load_dotenv()

client = Client(
    host="https://ollama.com",
    headers={'Authorization': 'Bearer ' + os.environ.get('OLLAMA_API_KEY')}
)

def llm(prompt):
    for part in client.chat('gpt-oss:120b', messages=[{"role": "user", "content": prompt}], stream=True):
        print(part['message']['content'], end='', flush=True)

# %%
llm("Hey, what's up?")
# Out:
# Hey! Not much—just here and ready to chat. How’s your day going? Anything fun or interesting on your mind that you’d like to talk about?

# %%
question = "I just discovered the course. Can I join now?"
answer = llm(question)
print(answer)
# Out:
# Absolutely—you can sign up right now! 🎉
#
# Here’s what you need to do to get started:
#
# | Step | What to Do | Details |
# |------|------------|---------|
# | **1️⃣ Check Availability** | Make sure there are open spots in the cohort you want. | Most courses have a live “Seats Available” indicator on the enrollment page. |
# | **2️⃣ Meet Prerequisites** | Confirm you meet any required background knowledge or equipment. | For example, a basic understanding of algebra for the **Data Science Foundations** track, or a laptop with a webcam for the **Presentation Skills** workshop. |
# | **3️⃣ Create / Log In to Your Account** | If you don’t already have a platform account, click **Sign Up** and fill in your name, email, and a password. | Existing users can just log in. |
# | **4️⃣ Fill Out the Enrollment Form** | Select the course, choose your preferred start date (if there are multiple batches), and answer any short questionnaire. | This helps us tailor the learning experience to your goals. |
# | **5️⃣ Pay (or Apply for a Scholarship)** | Pay the tuition via credit/debit card, PayPal, or an approved bank transfer. | If you need financial assistance, click **Apply for Scholarship** before submitting payment. |
# | **6️⃣ Confirmation** | After payment, you’ll receive an email with your receipt, login details, a welcome packet, and a link to the first live session. | Keep this email handy— it contains your access credentials and the course schedule. |
# | **7️⃣ Get Ready!** | Review the pre‑course material (usually a short PDF or video) and join the introductory Slack/Discord channel. | This is where you’ll meet fellow students and the instructor before day 1. |
#
# ---
#
# ### Quick FAQ
#
# | Question | Answer |
# |----------|--------|
# | **Is there a deadline?** | Most courses have rolling enrollment, but some have a cut‑off a week before the start date. Check the specific course page for its deadline. |
# | **What if the class is full?** | You can join the waitlist. We’ll notify you as soon as a spot opens, usually within 24–48 hours. |
# | **Can I switch cohorts later?** | Yes—if another start date becomes available, just contact support (support@yourcourse.com) and we’ll handle the transfer (subject to availability). |
# | **Do I get a certificate?** | Every completed course comes with a digital certificate you can add to LinkedIn or your résumé. |
# | **What if I have technical issues?** | Our tech‑support team is available 9 am–6 pm EST via live chat and email. They’ll resolve login or payment problems within a few hours. |
#
# ---
#
# ### Need a Hand?
#
# If you run into any hiccups while signing up—whether it’s a payment error, a question about prerequisites, or you just want to confirm the best start date—just let me know! I can:
#
# - Walk you through the registration steps in real‑time.
# - Check seat availability for the specific cohort you’re interested in.
# - Provide a direct link to the enrollment page.
#
# Looking forward to having you in the class! 🚀
#
# *Feel free to reply with any additional questions or the name of the course you’re eyeing, and I’ll get you rolling.*None

# %%
context = """
I just discovered the course. Can I still join?
Yes, but if you want to receive a certificate, you need to submit your project while we're still accepting submissions.

Course: I have registered for the LLM Zoomcamp. When can I expect to receive the confirmation email?
You don't need it. You're accepted. You can also just start learning and submitting homework (while the form is open) without registering. It is not checked against any registered list. Registration is just to gauge interest before the start date.

What is the video/zoom link to the stream for the "Office Hours" or live/workshop sessions?
The zoom link is only published to instructors/presenters/TAs. Students participate via YouTube Live and submit questions to Slido.

Cloud alternatives with GPU
Check the quota and reset cycle carefully. Potential options include Google Colab, Kaggle, Databricks.
"""

# %%
prompt = f"""
Your task is to answer questions from the course participants
based on the provided context.

Use the context to find relevant information and provide accurate
answers. If the answer is not found in the context,
respond with "I don't know."

Question:
{question}

Context:
{context}
"""

# %%
answer = llm(prompt)
print(answer)
# Out:
# Yes—you can still join the course.  Just keep in mind that if you’d like to earn a certificate you’ll need to complete and submit your project before the submission deadline (while we’re still accepting projects).None
